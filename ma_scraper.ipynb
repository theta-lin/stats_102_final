# %%
from random_user_agent.user_agent import UserAgent
from random_user_agent.params import SoftwareName, OperatingSystem

def get_random_user_agent():
    # you can also import SoftwareEngine, HardwareType, SoftwareType, Popularity from random_user_agent.params
    # you can also set number of user agents required by providing `limit` as parameter

    software_names = [SoftwareName.CHROME.value]
    operating_systems = [OperatingSystem.WINDOWS.value,
                         OperatingSystem.LINUX.value]

    user_agent_rotator = UserAgent(software_names=software_names,
                                   operating_systems=operating_systems,
                                   limit=100)

    return user_agent_rotator.get_random_user_agent()

# %%
from requests_cache import CachedSession
from datetime import timedelta
from lxml import html
import re
import time

class MetalArchives:
    session = CachedSession(backend='memory',
                            expire_after=timedelta(hours=1))
    site_url = 'https://www.metal-archives.com/'
    url_search_songs = 'search/ajax-advanced/searching/songs?'
    url_search_bands = 'search/ajax-advanced/searching/bands?'
    url_lyrics = 'release/ajax-view-lyrics/id/'
    lyrics_not_available = '(lyrics not available)'
    lyric_id_re = re.compile(r'id=.+[a-z]+.(?P<id>\d+)')
    band_name_re = re.compile(r'title="(?P<name>.*)\"')
    tags_re = re.compile(r'<[^>]+>')
    genres = ["black", "death", "doom", "stoner", "sludge", "electronic",
              "industrial", "experimental", "avant-garde", "folk", "viking",
              "pagan", "gothic", "grindcore", "groove", "heavy", "metalcore",
              "deathcore", "power", "progressive", "speed", "symphonic",
              "thrash"]

    @staticmethod
    def get_band_data(url):
        result = {}

        for attempt in range(0, 10):
            time.sleep(3)

            try:
                response = MetalArchives.session.get(url,
                                                     headers={'User-Agent': get_random_user_agent()})
            except:
                print('Error, retrying...', attempt, '                    ', end='\r')
                continue

            break


        tree = html.fromstring(response.content)
        result["name"] = \
            tree.xpath('//*[@id="band_info"]/h1/a/text()')
        result["url"] = \
            tree.xpath('//*[@id="band_info"]/h1/a/@href')
        result["genre"] = \
            tree.xpath(".//*[@id='band_stats']/dl[2]/dd[1]/text()")
        result["theme"] = \
            tree.xpath(".//*[@id='band_stats']/dl[2]/dd[2]/text()")
        result["label"] = \
            tree.xpath(".//*[@id='band_stats']/dl[2]/dd[3]/text()")
        result["country"] = \
            tree.xpath(".//*[@id='band_stats']/dl[1]/dd[1]/a/text()")
        result["location"] = \
            tree.xpath(".//*[@id='band_stats']/dl[1]/dd[2]/text()")
        result["status"] = \
            tree.xpath(".//*[@id='band_stats']/dl[1]/dd[3]/text()")
        result["date"] = \
            tree.xpath(".//*[@id='band_stats']/dl[1]/dd[4]/text()")
        years_active = \
            tree.xpath(".//*[@id='band_stats']/dl[3]/dd/text()")
        result["years"] = years_active

        for r in result.keys():
            if isinstance(result[r], list) and len(result[r]) == 1:
                result[r] = result[r][0]
            elif isinstance(result[r], list) and len(result[r]) == 0:
                result[r] = None
            if isinstance(result[r], str) and result[r] == 'N/A':
                result[r] = None
            #if r == "years":
            #    if "," in result[r]:
            #        years = result[r].split(",")
            #        result[r] = [y.rstrip().lstrip() for y in years]
            #    else:
            #        result[r] = [result[r].rstrip().lstrip()]
            if r == 'years' and result[r] is not None:
                result[r] = ''.join([y.strip().replace('\n', '') for y in result[r]])
            if r == "theme" and result[r] is not None:
                result[r] = result[r].split(",")
        return result

    def search_song(self, song_title="", band_name="", album_type="any",
                    excluded_album_types=None):

        excluded_album_types = excluded_album_types or []
        index = 0
        params = dict(bandName=band_name, songTitle=song_title, iDisplayStart=index)
        url = self.site_url + self.url_search_songs

        for attempt in range(0, 10):
            time.sleep(3)

            try:
                num = self.session.get(url, params=params,
                                headers={'User-Agent': get_random_user_agent()}).json()['iTotalRecords']
            except:
                print('Error, retrying...', attempt, '                    ', end='\r')
                continue

            break


        result = list()
        while index < num:
            for attempt in range(0, 10):
                time.sleep(3)

                try:
                    params['iDisplayStart'] = index
                    songs = self.session.get(url, params=params,
                                        headers={'User-Agent': get_random_user_agent()}).json()['aaData']

                    index += len(songs)

                    for song in songs:
                        if album_type != "any":
                            if song[2] != album_type:
                                continue
                        if song[2] in excluded_album_types:
                            continue
                        data = {"album_url": song[0][
                                             song[0].find('href="') + 6:song[0].find(
                                                 '" title=')],
                                "band_name": song[0][
                                             song[0].find('>') + 1:song[0].find('</a')],
                                "album_name": song[1][
                                              song[1].find('">') + 2:song[1].find('</a')],
                                "album_type": song[2],
                                "song_name": song[3],
                                "song_id": self.lyric_id_re.search(song[4]).group("id")}
                        result.append(data)

                    print("Song: ", index, '/', num, '-', int(index / num * 100) , '%          ', end='\r')

                except:
                    print('Error, retrying...', attempt, index, '/', num, '-', int(index / num * 100) , '%          ', end='\r')
                    continue

                break

        return result

    def search_band(self, band_name="", genre=""):
        index = 0
        params = dict(bandName=band_name, genre=genre, iDisplayStart=index)
        url = self.site_url + self.url_search_bands

        for attempt in range(0, 10):
            time.sleep(3)

            try:
                num = self.session.get(url, params=params,
                                        headers={'User-Agent': get_random_user_agent()}).json()['iTotalRecords']
            except:
                print('Error, retrying...                    ', end='\r')
                continue

            break

        result = list()
        while index < num:
            for attempt in range(0, 10):
                time.sleep(3)

                try:
                    params['iDisplayStart'] = index
                    bands = self.session.get(url, params=params,
                                        headers={'User-Agent': get_random_user_agent()}).json()['aaData']
                    index += len(bands)

                    for band in bands:
                        data = {
                            "url": band[0][band[0].find('href="') + 6:band[0].find('">')],
                            "name": band[0][band[0].find('">') + 2:band[0].find('</a>')],
                            "genre": band[1],
                            "country": band[2]}
                        result.append(data)

                    print("Band: ", index, '/', num, '-', int(index / num * 100) , '%          ', end='\r')

                except:
                    print('Error, retrying...', attempt, index, '/', num, '-', int(index / num * 100) , '%          ', end='\r')
                    continue

                break

        return result

    def get_lyrics_by_song_id(self, song_id):
        url = self.site_url + self.url_lyrics + song_id

        for attempt in range(0, 10):
            try:
                data = self.session.get(url,
                                    headers={'User-Agent': get_random_user_agent()})

            except:
                print('Error, retrying...', attempt, '                    ', end='\r')
                continue

            break

        lyrics = self.tags_re.sub('', data.text.strip())
        return lyrics
    
ma = MetalArchives()

# %%
import pandas as pd

# %%
bands_list = ma.search_band()
bands = pd.DataFrame(bands_list)
bands.to_csv('ma_bands.csv')

# %%
bands = pd.read_csv('ma_bands.csv', index_col=0)
bands
# Out:
#                                                       url          name  \
# 0       https://www.metal-archives.com/bands/%21T.O.O....    !T.O.O.H.!
# 1       https://www.metal-archives.com/bands/%21%C3%BA...         !úl..
# 2       https://www.metal-archives.com/bands/%24Greed%...       $Greed$
# 3       https://www.metal-archives.com/bands/%24ilverd...  $ilverdollar
# 4       https://www.metal-archives.com/bands/%24lamboy...      $lamboy$
# ...                                                   ...           ...
# 130767  https://www.metal-archives.com/bands/%EC%A3%BC...            주작
# 130768  https://www.metal-archives.com/bands/%EC%B5%9C...           최일민
# 130769  https://www.metal-archives.com/bands/%ED%8F%90...            폐허
# 130770  https://www.metal-archives.com/bands/%ED%94%BC...          피해의식
# 130771  https://www.metal-archives.com/bands/%ED%95%B4...            해독
#
#                                                     genre        country
# 0                       Progressive Death Metal/Grindcore        Czechia
# 1                                       Death/Black Metal        Czechia
# 2                                      Heavy/Thrash Metal  United States
# 3                                       Heavy/Power Metal         Sweden
# 4       Death Metal/Grindcore (early); Slam/Brutal Dea...  United States
# ...                                                   ...            ...
# 130767                                        Heavy Metal   Korea, South
# 130768                            Heavy Metal/Rock, Shred   Korea, South
# 130769               Dark Ambient/Atmospheric Black Metal   Korea, South
# 130770                                        Heavy Metal   Korea, South
# 130771                                        Heavy Metal   Korea, South
#
# [130772 rows x 4 columns]

# %%
def get_band_data_chunk(chunk_num, chunk_id):
    print('Chunk:', chunk_id, '/', chunk_num)
    
    chunk_size = bands.shape[0] // chunk_num
    begin = chunk_size * chunk_id
    end = begin + chunk_size
    if (chunk_id == chunk_num - 1):
        end = bands.shape[0]
    
    data = list()
    for row in range(begin, end):
        print('Band:', row - begin, '/', end - begin, '-', int((row - begin) / (end - begin) * 100) , '%          ', end='\r')
        data.append(ma.get_band_data(bands.loc[row, 'url']))
    return data

# %%
chunk_num = int(input('Number of chunks:'))
chunk_id = int(input('ID of current chunk:'))
data = pd.DataFrame(get_band_data_chunk(chunk_num, chunk_id))
data.to_csv('ma_bands_data_' + str(chunk_id) + '.csv')
# Out:
# Number of chunks:10000
# ID of current chunk:0
# Chunk: 0 / 10000
# Band: 12 / 13 - 92 %

# %%
data_sample = pd.read_csv('ma_bands_data_sample.csv', index_col=0)
data_sample
# Out:
#                           name  \
# 0                   !T.O.O.H.!
# 1                        !úl..
# 2                      $Greed$
# 3                 $ilverdollar
# 4                     $lamboy$
# 5                      $lutrot
# 6             $uicide $olution
# 7   '. . . [l]ight am I' . . .
# 8                         'Ain
# 9                    'Iisnááhí
# 10                      'Neath
# 11                  ('M') Inc.
# 12                   (((...)))
#
#                                                   url  \
# 0   https://www.metal-archives.com/bands/%21T.O.O....
# 1   https://www.metal-archives.com/bands/%21%C3%BA...
# 2   https://www.metal-archives.com/bands/%24Greed%...
# 3   https://www.metal-archives.com/bands/%24ilverd...
# 4   https://www.metal-archives.com/bands/%24lamboy...
# 5   https://www.metal-archives.com/bands/%24lutrot...
# 6   https://www.metal-archives.com/bands/%24uicide...
# 7   https://www.metal-archives.com/bands/%27._._._...
# 8   https://www.metal-archives.com/bands/%27Ain/35...
# 9   https://www.metal-archives.com/bands/%27Iisn%C...
# 10  https://www.metal-archives.com/bands/%27Neath/...
# 11  https://www.metal-archives.com/bands/%28%27M%2...
# 12  https://www.metal-archives.com/bands/%28%28%28...
#
#                                                 genre  \
# 0                   Progressive Death Metal/Grindcore
# 1                                   Death/Black Metal
# 2                                  Heavy/Thrash Metal
# 3                                   Heavy/Power Metal
# 4   Death Metal/Grindcore (early); Slam/Brutal Dea...
# 5                             Slam/Brutal Death Metal
# 6                                         Heavy Metal
# 7                                         Black Metal
# 8                                     Symphonic Metal
# 9                                         Black Metal
# 10                            Progressive Death Metal
# 11                                        Death Metal
# 12                             Drone/Doom Metal/Noise
#
#                                                 theme                 label  \
# 0   ['Misanthropy', ' Violence', ' Rape', ' Deprav...                   NaN
# 1                   ['Destiny', ' Emotions', ' Life']                   NaN
# 2                           ['Politics', ' Humanity']  Unsigned/independent
# 3             ['Occult', ' Fantasy', ' Human issues']                   NaN
# 4                              ['Memes', ' Nonsense']  Unsigned/independent
# 5                                            ['Gore']                   NaN
# 6                   ['Darkness', ' Death', ' Horror']                   NaN
# 7   ['Conquering', ' Destroying', ' Possessing', '...                   NaN
# 8                ['Poetry', ' Emotions', ' Solitude']  Unsigned/independent
# 9   ['Navajo/Native American mythology', " Diné Ba...  Unsigned/independent
# 10                            ['Life', ' Melancholy']                   NaN
# 11                                                NaN  Unsigned/independent
# 12                                   ['Instrumental']  Unsigned/independent
#
#           country                         location    status  date  \
# 0         Czechia                           Prague    Active  1993
# 1         Czechia                           Prague  Split-up  2002
# 2   United States          Los Angeles, California   On hold  1992
# 3          Sweden           Nyköping, Södermanland    Active  1996
# 4   United States                   Cary, Illinois    Active  2016
# 5   United States  Nevada / North Carolina / Texas  Split-up  2013
# 6       Singapore                        Singapore   On hold  1998
# 7          Canada       Cartier/Kitchener, Ontario   Unknown  1996
# 8          Mexico                      Mexico City    Active  2010
# 9   United States          Albuquerque, New Mexico    Active  2018
# 10      Australia             Brisbane, Queensland  Split-up  2003
# 11  United States          Apopka/Orlando, Florida   Unknown  2009
# 12      Indonesia                       Yogyakarta    Active  2012
#
#                                               years
# 0   1990-1993 (as),1993-2005,2011-2013,2017-present
# 1                                         2002-2011
# 2              1992-1994 (as),1994-1996 (as),1999-?
# 3                                      1996-present
# 4                            2016-2017,2017-present
# 5                               2013-2015,2017-2019
# 6                               1998-2006,2008-2014
# 7                                            1996-?
# 8                                      2010-present
# 9                                      2018-present
# 10                                        2003-2012
# 11                                 2009 (as),2009-?
# 12                                     2012-present

# %%
def get_song_chunk(chunk_num, chunk_id):
    print('Chunk:', chunk_id, '/', chunk_num)
    
    chunk_size = bands.shape[0] // chunk_num
    begin = chunk_size * chunk_id
    end = begin + chunk_size
    if (chunk_id == chunk_num - 1):
        end = bands.shape[0]
    
    songs = list()
    for row in range(begin, end):
        print('Band:', row - begin, '/', end - begin, '-', int((row - begin) / (end - begin) * 100) , '%          ', end='\r')
        songs += ma.search_song(band_name=bands.loc[row, 'name'])
    return songs

# %%
chunk_num = int(input('Number of chunks:'))
chunk_id = int(input('ID of current chunk:'))
songs = pd.DataFrame(get_song_chunk(chunk_num, chunk_id))
songs.to_csv('ma_songs_' + str(chunk_id) + '.csv')

# %%
songs_sample = pd.read_csv('ma_songs_sample.csv', index_col=0)
songs_sample
# Out:
#                                              album_url   band_name  \
# 0    https://www.metal-archives.com/bands/%21T.O.O....  !T.O.O.H.!
# 1    https://www.metal-archives.com/bands/%21T.O.O....  !T.O.O.H.!
# 2    https://www.metal-archives.com/bands/%21T.O.O....  !T.O.O.H.!
# 3    https://www.metal-archives.com/bands/%21T.O.O....  !T.O.O.H.!
# 4    https://www.metal-archives.com/bands/%21T.O.O....  !T.O.O.H.!
# ..                                                 ...         ...
# 816  https://www.metal-archives.com/bands/.../35402...         ...
# 817  https://www.metal-archives.com/bands/.../35402...         ...
# 818  https://www.metal-archives.com/bands/.../35402...         ...
# 819  https://www.metal-archives.com/bands/.../35402...         ...
# 820  https://www.metal-archives.com/bands/.../35402...         ...
#
#                         album_name   album_type                   song_name  \
# 0              Democratic Solution  Full-length  Aura & Ziata (new version)
# 1              Democratic Solution  Full-length     Boubelovo životakončení
# 2              Democratic Solution  Full-length         Demokratické řešení
# 3              Democratic Solution  Full-length                Instrumental
# 4              Democratic Solution  Full-length               Kokarda pýchy
# ..                             ...          ...                         ...
# 816            Suffering Existence         Demo                       I.S.K
# 817            Suffering Existence         Demo  Leave This Mortals Remains
# 818  The Path Toward Forgetfulness        Split  Ascending to the Night Sky
# 819  The Path Toward Forgetfulness        Split         Like Shooting Stars
# 820  The Path Toward Forgetfulness        Split       Vanishing Among Tides
#
#      song_id
# 0    2667201
# 1    2667192
# 2    2667195
# 3    2667203
# 4    2667194
# ..       ...
# 816  1442252
# 817  1442251
# 818  2281629
# 819  2281630
# 820  2281631
#
# [821 rows x 6 columns]
